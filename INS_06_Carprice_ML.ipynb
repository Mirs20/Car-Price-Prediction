# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest,f_classif
  
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
dataset=pd.read_csv(r"C:\Users\A\Documents\flip robo\created\Dataset/CarPricePrediction_Dataset.csv")
dataset.head()
# Out:
#    Unnamed: 0                                           car_urls  \
# 0           0  https://www.cardekho.com/buy-used-car-details/...
# 1           1  https://www.cardekho.com/buy-used-car-details/...
# 2           2  https://www.cardekho.com/buy-used-car-details/...
# 3           3  https://www.cardekho.com/buy-used-car-details/...
# 4           4  https://www.cardekho.com/buy-used-car-details/...
#
#                     brand       city                variant       price  \
# 0         2016 Honda Jazz  ahmedabad                  V CVT   6.28 Lakh
# 1   2018 Mahindra Marazzo  ahmedabad                     M8  10.15 Lakh
# 2  2015 Hyundai Grand i10  ahmedabad                 Sportz   4.51 Lakh
# 3       2019 Jeep Compass  ahmedabad  1.4 Limited Plus BSIV  16.78 Lakh
# 4         2016 Honda Jazz  ahmedabad        1.2 V AT i VTEC   6.29 Lakh
#
#           run    fuel      Trans
# 0  39,821 kms  Petrol  Automatic
# 1  41,071 kms  Diesel     Manual
# 2  67,525 kms  Petrol     Manual
# 3  32,294 kms  Petrol  Automatic
# 4  15,385 kms  Petrol  Automatic

# %%
def fun_year(x):
    a=int(x.split(' ')[0])
    return a
def fun_brand(x):
    a=x.split(' ')[1]
    return a
def fun_model(x):
    if len(x.split(' '))==3:
        a=x.split(' ')[2]
    elif len(x.split(' '))>3:
        a=x.split(' ')[2]+' '+x.split(' ')[3]
    return a

def fun_price(x):
    if 'Lakh' in x:
        a=float(x.split(' ')[0])  
        return a
    elif  "Cr" in x:
        a=float(x.split(' ')[0]) *100
        return a
    
def fun_run(x):
    a=float(x.split(' ')[0].replace(',',''))
    return a

# %%
dataset['reg_year']=dataset['brand'].apply(fun_year)

# %%
dataset['Brand']=dataset['brand'].apply(fun_brand)

# %%
dataset['model']=dataset['brand'].apply(fun_model)

# %%
dataset['price(Lakh)']=dataset['price'].apply(fun_price)

# %%
dataset['run(kms)']=dataset['run'].apply(fun_run)

# %%
dataset.head()
# Out:
#    Unnamed: 0                                           car_urls  \
# 0           0  https://www.cardekho.com/buy-used-car-details/...
# 1           1  https://www.cardekho.com/buy-used-car-details/...
# 2           2  https://www.cardekho.com/buy-used-car-details/...
# 3           3  https://www.cardekho.com/buy-used-car-details/...
# 4           4  https://www.cardekho.com/buy-used-car-details/...
#
#                     brand       city                variant       price  \
# 0         2016 Honda Jazz  ahmedabad                  V CVT   6.28 Lakh
# 1   2018 Mahindra Marazzo  ahmedabad                     M8  10.15 Lakh
# 2  2015 Hyundai Grand i10  ahmedabad                 Sportz   4.51 Lakh
# 3       2019 Jeep Compass  ahmedabad  1.4 Limited Plus BSIV  16.78 Lakh
# 4         2016 Honda Jazz  ahmedabad        1.2 V AT i VTEC   6.29 Lakh
#
#           run    fuel      Trans  reg_year     Brand      model  price(Lakh)  \
# 0  39,821 kms  Petrol  Automatic      2016     Honda       Jazz         6.28
# 1  41,071 kms  Diesel     Manual      2018  Mahindra    Marazzo        10.15
# 2  67,525 kms  Petrol     Manual      2015   Hyundai  Grand i10         4.51
# 3  32,294 kms  Petrol  Automatic      2019      Jeep    Compass        16.78
# 4  15,385 kms  Petrol  Automatic      2016     Honda       Jazz         6.29
#
#    run(kms)
# 0   39821.0
# 1   41071.0
# 2   67525.0
# 3   32294.0
# 4   15385.0

# %%
dataset[55:60]
# Out:
#     Unnamed: 0                                           car_urls  \
# 55          55  https://www.cardekho.com/used-car-details/used...
# 56          56  https://www.cardekho.com/used-car-details/used...
# 57          57  https://www.cardekho.com/used-car-details/used...
# 58          58  https://www.cardekho.com/used-car-details/used...
# 59          59  https://www.cardekho.com/used-car-details/used...
#
#                        brand       city              variant       price  \
# 55    2010 Rolls-Royce Ghost  ahmedabad             Standard     1.80 Cr
# 56         2020 BMW 7 Series  ahmedabad  740Li DPE Signature     1.10 Cr
# 57         2020 BMW 7 Series  ahmedabad  740Li DPE Signature     1.10 Cr
# 58         2019 BMW 3 Series  ahmedabad         330i M Sport  49.00 Lakh
# 59  2017 Toyota Land Cruiser  ahmedabad                   VX     1.35 Cr
#
#            run    fuel      Trans  reg_year        Brand         model  \
# 55  28,000 kms  Petrol  Automatic      2010  Rolls-Royce         Ghost
# 56  11,000 kms  Petrol  Automatic      2020          BMW      7 Series
# 57  13,000 kms  Petrol  Automatic      2020          BMW      7 Series
# 58   5,000 kms  Petrol  Automatic      2019          BMW      3 Series
# 59  85,000 kms  Diesel  Automatic      2017       Toyota  Land Cruiser
#
#     price(Lakh)  run(kms)
# 55        180.0   28000.0
# 56        110.0   11000.0
# 57        110.0   13000.0
# 58         49.0    5000.0
# 59        135.0   85000.0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7960 entries, 0 to 7959
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   7960 non-null   int64
#  1   car_urls     7960 non-null   object
#  2   brand        7960 non-null   object
#  3   city         7960 non-null   object
#  4   variant      7960 non-null   object
#  5   price        7960 non-null   object
#  6   run          7960 non-null   object
#  7   fuel         7960 non-null   object
#  8   Trans        7960 non-null   object
#  9   reg_year     7960 non-null   int64
#  10  Brand        7960 non-null   object
#  11  model        7960 non-null   object
#  12  price(Lakh)  7939 non-null   float64
#  13  run(kms)     7960 non-null   float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 870.8+ KB

# %%
df=dataset.drop(columns=['car_urls','price','brand','run','Unnamed: 0'],axis=1)
df.head()
# Out:
#         city                variant    fuel      Trans  reg_year     Brand  \
# 0  ahmedabad                  V CVT  Petrol  Automatic      2016     Honda
# 1  ahmedabad                     M8  Diesel     Manual      2018  Mahindra
# 2  ahmedabad                 Sportz  Petrol     Manual      2015   Hyundai
# 3  ahmedabad  1.4 Limited Plus BSIV  Petrol  Automatic      2019      Jeep
# 4  ahmedabad        1.2 V AT i VTEC  Petrol  Automatic      2016     Honda
#
#        model  price(Lakh)  run(kms)
# 0       Jazz         6.28   39821.0
# 1    Marazzo        10.15   41071.0
# 2  Grand i10         4.51   67525.0
# 3    Compass        16.78   32294.0
# 4       Jazz         6.29   15385.0

# %%
df.shape
# Out:
# (7960, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7960 entries, 0 to 7959
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   city         7960 non-null   object
#  1   variant      7960 non-null   object
#  2   fuel         7960 non-null   object
#  3   Trans        7960 non-null   object
#  4   reg_year     7960 non-null   int64
#  5   Brand        7960 non-null   object
#  6   model        7960 non-null   object
#  7   price(Lakh)  7939 non-null   float64
#  8   run(kms)     7960 non-null   float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 559.8+ KB

# %%
df.describe()
# Out:
#           reg_year  price(Lakh)       run(kms)
# count  7960.000000  7939.000000    7960.000000
# mean   2017.145101    10.710562   49072.964824
# std       2.460631    18.869155   42868.510758
# min    2002.000000     1.000000     600.000000
# 25%    2016.000000     4.740000   25911.250000
# 50%    2017.000000     6.580000   43368.000000
# 75%    2019.000000     9.480000   67241.000000
# max    2022.000000   210.000000  950000.000000

# %% [markdown]
# * Missing data Analysis

# %%
miss=pd.DataFrame(df.isna().sum(),index=df.columns)
miss[miss[0]!=0]
# Out:
#               0
# price(Lakh)  21

# %%
df.isna().sum()
# Out:
# city            0
# variant         0
# fuel            0
# Trans           0
# reg_year        0
# Brand           0
# model           0
# price(Lakh)    21
# run(kms)        0
# dtype: int64

# %%
misp=pd.DataFrame((df.isna().sum()*100/df.shape[0])).reset_index()
misp[misp[0]!=0]
# Out:
#          index         0
# 7  price(Lakh)  0.263819

# %%
df.isna().sum().sum()
# Out:
# 21

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.isnull(),cmap='Accent')
plt.show()

# %%
plt.figure(figsize=(10,3))
ax = sns.pointplot('index',0,data=misp,color='g')
plt.xticks(rotation =90,fontsize =7)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()

# %%
df.columns[misp[misp[0]!=0].index]
# Out:
# Index(['price(Lakh)'], dtype='object')

# %%
df.dropna(axis=0,inplace=True)
df.reset_index(drop=True)
# Out:
#            city                variant    fuel      Trans  reg_year     Brand  \
# 0     ahmedabad                  V CVT  Petrol  Automatic      2016     Honda
# 1     ahmedabad                     M8  Diesel     Manual      2018  Mahindra
# 2     ahmedabad                 Sportz  Petrol     Manual      2015   Hyundai
# 3     ahmedabad  1.4 Limited Plus BSIV  Petrol  Automatic      2019      Jeep
# 4     ahmedabad        1.2 V AT i VTEC  Petrol  Automatic      2016     Honda
# ...         ...                    ...     ...        ...       ...       ...
# 7934    lucknow                    VDi  Diesel     Manual      2018    Maruti
# 7935    lucknow                AMT VXI  Petrol  Automatic      2019    Maruti
# 7936    lucknow        1.2 Revotron XT  Petrol     Manual      2019      Tata
# 7937    lucknow                      V  Petrol     Manual      2011    Toyota
# 7938    lucknow           RXT Optional  Petrol     Manual      2016   Renault
#
#               model  price(Lakh)  run(kms)
# 0              Jazz         6.28   39821.0
# 1           Marazzo        10.15   41071.0
# 2         Grand i10         4.51   67525.0
# 3           Compass        16.78   32294.0
# 4              Jazz         6.29   15385.0
# ...             ...          ...       ...
# 7934  Vitara Brezza         6.93   94515.0
# 7935          Swift         6.20   35919.0
# 7936          Tiago         5.13   26641.0
# 7937     Etios Liva         2.43   61640.0
# 7938           KWID         2.43   51985.0
#
# [7939 rows x 9 columns]

# %%
df.shape
# Out:
# (7939, 9)

# %%
cont=[]
cat=[]
for i in df.columns:
    if df[i].dtype==np.object:
        cat.append(i)
    else:
        cont.append(i)
print('Number of Numeric variables :',len(cont),'\n')
print(cont)
print("--------------------------")
print('Number of Objective  variables :',len(cat),'\n')
print(cat)
# Out:
# Number of Numeric variables : 3
#
# ['reg_year', 'price(Lakh)', 'run(kms)']
# --------------------------
# Number of Objective  variables : 6
#
# ['city', 'variant', 'fuel', 'Trans', 'Brand', 'model']

# %%
for i in cat:
    print(i,":\n")
    print(len(df[i].unique()))
    print('______________________________\n')
# Out:
# city :
#
# 12
# ______________________________
#
# variant :
#
# 573
# ______________________________
#
# fuel :
#
# 5
# ______________________________
#
# Trans :
#
# 2
# ______________________________
#
# Brand :
#
# 23
# ______________________________
#
# model :
#
# 141
# ______________________________

# %% [markdown]
# * Distribution of continuois variables

# %%
plt.figure(figsize=(20,100))
sns.set_palette('bright')
graph=1

for column in cont:
    if graph<=len(cont):
        ax=plt.subplot(19,2,graph)
        sns.distplot(df[column],color='purple')
        plt.xlabel(column,fontsize=15)
        
    graph+=1
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(10,10))
sns.set_palette('bright')

graph=1

for column in cont:
    if graph<=len(cont):
        ax=plt.subplot(3,1,graph)
        sns.scatterplot(x=df[column],y=df['price(Lakh)'],color='m')
        plt.xlabel(column,fontsize=15)
        
    graph+=1
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(15,100))
sns.set_palette('Set1')

graph=1

for column in cat:
    if graph<=len(cat):
        ax=plt.subplot(6,1,graph)
        sns.countplot(y=df[column])
        plt.ylabel(column,fontsize=15)
    graph+=1
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(10,5))
sns.set_palette('Set1')
plt.style.use('default')
sns.violinplot(x=df['city'],y=df['price(Lakh)'])
plt.xlabel('city',fontsize=10) 
plt.xticks(rotation='90')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.set_palette('Set1')
plt.style.use('default')
sns.violinplot(x=df['Brand'],y=df['price(Lakh)'])
plt.xlabel('Brand',fontsize=10) 
plt.xticks(rotation='90')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.set_palette('Set1')
plt.style.use('default')
sns.violinplot(x=df['Trans'],y=df['price(Lakh)'])
plt.xlabel('Trans',fontsize=10) 
plt.xticks(rotation='90')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.set_palette('Set1')
plt.style.use('default')
sns.violinplot(x=df['fuel'],y=df['price(Lakh)'])
plt.xlabel('fuel',fontsize=10) 
plt.xticks(rotation='90')
plt.show()

# %%
plt.figure(figsize=(21,10))
sns.set_palette('bright')

graph=1

for column in cont:
    if graph<=len(cont):
        ax=plt.subplot(2,2,graph)
        sns.boxplot(y=df[column],color='lightgreen')
        plt.ylabel(column,fontsize=20)
        plt.yticks(fontsize=20)
    graph+=1
plt.show()
plt.tight_layout()

# %%
inf=['reg_year','run(kms)']

# %% [markdown]
# ##### IQR method

# %%
data=df.copy()

# %%
row_before=data.shape[0]
row_before
# Out:
# 7939

# %%
q1=data.quantile(0.25)
q3=data.quantile(0.75)
iqr=q3-q1
lower=q1-(1.5*iqr)
upper=q3+(1.5*iqr)
Quant=pd.DataFrame({'Q1':q1,'Q3':q3,'IQR':iqr,'Lower limit':lower,'Upper limit':upper})
Quant
# Out:
#                    Q1        Q3       IQR  Lower limit  Upper limit
# reg_year      2016.00   2019.00      3.00      2011.50      2023.50
# price(Lakh)      4.74      9.48      4.74        -2.37        16.59
# run(kms)     25897.50  67211.00  41313.50    -36072.75    129181.25

# %%
for i in data[inf].columns:
    ind=np.where(data[i]>upper[i])
    data=data.drop(data.index[ind])
    data.reset_index()
    
for i in data[inf].columns:
    inx=np.where(data[i]<lower[i])
    data=data.drop(data.index[inx])
    data.reset_index()

# %%
row_after=data.shape[0]
row_after
# Out:
# 7751

# %%
loss2=((row_before-row_after)/row_before)*100
loss2
# Out:
# 2.368056430280892

# %% [markdown]
# #### Z score

# %%
data=df.copy()
rows_before1=data.shape[0]
rows_before1
# Out:
# 7939

# %%
from scipy.stats import zscore

z1=np.abs(zscore(data[inf]))
data=data[(z1<3).all(axis=1)]

# %%
rows_after1=data.shape[0]
rows_after1
# Out:
# 7864

# %%
loss1=((rows_before1-rows_after1)/rows_before1)*100
loss1
# Out:
# 0.9447033631439727

# %%
plt.figure(figsize=(5,5))
sns.set_palette('bright')


graph=1

for column in inf:
    if graph<=len(inf):
        ax=plt.subplot(2,1,graph)
        sns.distplot(df[column],color='red')
        sns.distplot(data[column],color='blue')
        plt.xlabel(column,fontsize=5)
        plt.title("Distribution of {} Before and After Outlier treatment ".format(column),fontsize=5)
        plt.legend(['Before Outlier treatment','After Outlier treatment'],fontsize=5)
        plt.xticks(fontsize=5)
        plt.yticks(fontsize=5)
    graph+=1
plt.show()
plt.tight_layout()

# %% [markdown]
# * The project doesn't involve removal outliers due to:
#
#   1] The outlliers are due to natural variation i population
#
#   2] The preprocessing involves transformation to reduce skewness in data
#
#   3] The alorithms involved in training are tree base algorithms

# %%
df.shape
# Out:
# (7939, 9)

# %% [markdown]
# #### Encoding with LabelEncoder

# %%
df.head()
# Out:
#         city                variant    fuel      Trans  reg_year     Brand  \
# 0  ahmedabad                  V CVT  Petrol  Automatic      2016     Honda
# 1  ahmedabad                     M8  Diesel     Manual      2018  Mahindra
# 2  ahmedabad                 Sportz  Petrol     Manual      2015   Hyundai
# 3  ahmedabad  1.4 Limited Plus BSIV  Petrol  Automatic      2019      Jeep
# 4  ahmedabad        1.2 V AT i VTEC  Petrol  Automatic      2016     Honda
#
#        model  price(Lakh)  run(kms)
# 0       Jazz         6.28   39821.0
# 1    Marazzo        10.15   41071.0
# 2  Grand i10         4.51   67525.0
# 3    Compass        16.78   32294.0
# 4       Jazz         6.29   15385.0

# %%
df.shape
# Out:
# (7939, 9)

# %%
for i in cat:
    print(i,":\n")
    print(df[i].unique())
    print('______________________________\n')
# Out:
# city :
#
# ['ahmedabad' 'bangalore' 'mumbai' 'jaipur' 'gurgaon' 'delhi-ncr' 'chennai'
#  'pune' 'hyderabad' 'kolkata' 'agra' 'lucknow']
# ______________________________
#
# variant :
#
# ['V CVT' 'M8' 'Sportz' '1.4 Limited Plus BSIV' '1.2 V AT i VTEC'
#  '1.6 VTVT AT SX' 'W11 BSIV' '2.5 G' '1.6 VTVT S Option' 'S MT' 'W8 FWD'
#  '1.6 CRDi SX' '3.0' 'Standard' '740Li DPE Signature' '330i M Sport' 'VX'
#  '1.4 Limited' 'i-VTEC CVT ZX' 'T' 'ZDi' 'S i-Vtech' '1.2 AMT Zeta BSIV'
#  'Petrol RXS CVT' 'T Option' 'RXZ Turbo CVT' 'Asta 1.4 CRDi' 'VXI'
#  'Petrol RxL' 'W6 2WD' '1.2 Kappa Sportz BSIV' 'VTVT 1.6 SX' 'VX CVT'
#  'GTX Plus' '1.2 TSI Highline AT' 'ZX CVT' '1.6 VTVT SX Plus' 'AT W10 FWD'
#  '1.2 Kappa Magna BSIV' 'ZXi' 'VXi Plus' 'GLS AT' '1.2 Asta' 'LXI'
#  'VXI AMT 1.2' 'VXI BS IV' 'XZ Plus Diesel' '1.2 Delta' 'W6' '1.4 Delta'
#  '1.2 TSI Highline Plus AT' 'X' 'i VTEC CVT SV' 'LXI BS IV' 'RXL'
#  'Sportz 1.2' 'RXL BSVI' '110PS Diesel RxS AMT' 'DDiS 200 Delta' 'ZXI'
#  'D75 K2' '1.0 RXT Opt BSIV' 'VXI 1.2' 'Magna' 'Turbo XV Premium' 'T BSIV'
#  'Magna Plus' 'Era Plus' '1.2 Spotz' 'Magna Optional 1.2' '1.2 Sportz'
#  'Magna AT' 'LXI Optional' '1.3 Sigma' '1.2 Sigma' 'VDi' 'LX' 'XZ' 'W7'
#  'VXI CNG BSIV' '2.5 VX (Diesel) 8 Seater BS IV' '85PS RxL'
#  'sDrive 20d xLine' 'LTZ' 'LTZ AT' '2.4L 4WD AT' 'LS' 'S AT i-Vtech'
#  'AX Opt 4-Str Hard Top Diesel' '1.3 Delta' 'Sharp DCT'
#  '1.4 Longitude Option' '1.8 TSI AT Style' 'W8 Option' 'Asta BSIV'
#  '1.2 Asta Dual Tone' 'VXI Plus' '1.2 Revotron XZA Plus' 'V BSIV'
#  '1.4 Alpha' 'mFALCON G80 K8' '1.0 TSI Ambition AT' '1.5 TDI AT Elegance'
#  '1.5 TDCi Titanium BSIV' '3.0 D SE' '3.6 4X4' 'RXZ AWD' 'Delta'
#  'SX Opt Turbo' '1.5D Titanium MT' 'VX i-VTEC' 'SX Turbo' '1.2 Kappa Asta'
#  'Asta' 'Sharp Diesel MT' 'RXT' 'Asta Option 1.4 CRDi' '1.0 RXT Optional'
#  '85PS Diesel RxL' 'V MT' '1.2 V i VTEC' '1.2 MPI Highline' '1.5 XV'
#  'VDI SHVS' 'Alpha Automatic BSIV' 'Select Diesel MT 7 STR' 'VTVT 1.6 EX'
#  '1.2 Kappa Sportz Dual Tone' 'i DTEC V' 'XZ Turbo' '1.2 Revotron XT'
#  '85PS Diesel RxS' 'SX Plus AMT' 'SV' 'Style Plus 1.8 TSI AT'
#  'T Option BSIV' 'VVT VXI' 'VXI 2019-2022' 'RXZ BSIV' '1.2 VX i VTEC'
#  'SX Turbo BSIV' 'W8 Option Diesel BSIV' 'ZXI Optional AMT BSIV'
#  'i VTEC CVT VX' '1.2 Revotron XZ' 'VDI' 'VXI Opt' '1.2 Zeta' 'VX Diesel'
#  'i-VTEC VX' '2010-2014 VXI' 'VTVT 1.6 AT SX Option' '1.2 Alpha'
#  '1.6 VTVT AT SX Plus' 'Alpha BSIV' 'A' 'HTX D' 'i VTEC V' 'i-DTEC VX'
#  'ZXi Plus' '1.6 VTVT E Plus' '1.2 Magna Executive' '1.5 Revotorq XM'
#  'S2 7 Seater' 'i-VTEC CVT VX' 'XZ Plus Dark Edition' 'Petrol Asta Option'
#  'AMT 1.0 S' 'Asta 1.2' 'XV CVT' 'Alpha DDiS 200 SH' '200 CGI Sport'
#  '3.0 TDI Quattro Technology' 'S Hybrid' '2.0 TDI Style' '200 d Sport'
#  'sDrive20d' '1.6 VTVT S' 'XM Diesel' 'CNG LXI' 'VTVT 1.6 SX Option'
#  '1.2 Revotron XM' '1.4 Asta Option' 'i-VTEC S' 'GL MT' 'SX Option'
#  '1.6 MPI Ambition BSIV' 'Diesel Highline 1.2L' '1.6 Highline'
#  '1.4 AT Alpha' 'ZXI 1.2' 'M6 8Str' '1.5 S MT' 'Ambiente 2.0 TDI CR AT'
#  '1.5 Revotorq XZ' 'W7 BSIV' 'Alpha AT' 'AMT VXI' '1.2 SX' 'ZDi Plus'
#  'ZXI AMT' 'S i-VTEC' '1.3 Alpha' 'V Petrol BSIV' 'S11' '1.2 CVT Alpha'
#  'R W10 FWD' '1.5 TDI Highline' '1.2 Asta Option' '1.6 SX VTVT' '1.4 VTVT'
#  '1.6 VTVT SX Plus Dual Tone' 'Asta Option 1.2' '1.1 CRDi SX'
#  'Magna CNG BSIV' 'XV Premium' 'SX Plus Turbo DCT' '1.0 TSI Highline Plus'
#  'S400' 'Maybach S560' 'A 200' 'xDrive30d DPE Signature'
#  '2.0 R-Dynamic S Diesel' '1.0 MPI Highline Plus' 'XT' 'Sportz BSIV'
#  'CRDi Sportz' '1.6 CRDi SX Option' 'S' '1.3 Turbo XV' 'S Petrol BSIV'
#  '2.0 Sport Plus BSIV' '1.8 VL CVT' '1.5 Diesel Trend BSIV'
#  '1.2 CRDi Asta' 'RXZ' 'Sportz AMT BSIV' '1.4 Sport' '1.4 Limited Option'
#  'AMT Sportz' 'RXZ Turbo' '320d Sedan' 'ZXI Plus' 'VXI MT BSIV' 'Alpha'
#  '35 TDI' '1.2 CRDi Sportz' 'S i-Dtech' 'Sportz 1.4 CRDi' 'mHAWK100 T8'
#  'VXI Plus 2019-2022' 'VX AT' 'Magna 1.4 CRDi' 'i DTEC S' 'i-VTEC CVT V'
#  'GD' 'i-VTEC V' 'SX iMT' 'ZDi Plus Dual Tone' '1.4 E Plus CRDi' 'AMT ZDI'
#  '1.2 Sigma BSIV' 'D Lite Plus' '1.5 DV5 MT Titanium' '3.0 Diesel'
#  '1.6 TDI Ambition Plus' 'Vxi BSIV' 'VDi AMT' 'XZ Plus Kaziranga Edition'
#  'Diesel XV' '1.5 V MT' 'W10 2WD' 'AMT ZXI' 'XZ Plus' 'Sigma BSIV'
#  'ZXI MT BSIV' '1.2 CVT Zeta' 'VDI BSIV' '1.2 G' 'XM plus'
#  '1.5 Petrol RXL' '520d M Sport' '3.2 Titanium AT 4X4' '2.8 2WD MT BSIV'
#  'Titanium Plus 4X2 AT' 'TRD 4X4 AT' 'ZXI BSIV' '1.5 Revotorq XZA Plus'
#  '1.99 S10' '1.2 Delta BSIV' 'mFALCON D75 K8' '1.6 CRDi S' 'XZA Plus AMT'
#  '1.0 RXT Opt' '1.6 SX Option' 'XZ BSIV' '1.2 MPI Trendline' 'VX MT' 'XM'
#  'W6 1.99 mHawk' 'XZA Plus AMT Diesel' '2.8 GX AT BSIV' 'XE'
#  'SX Plus Turbo DCT BSIV' 'VXI Optional' '1.6 SX' 'i-VTEC ZX'
#  '1.2 Zeta BSIV' 'KRAZ' 'LXI Optional-O' 'Zeta' 'W9 2WD' '2.4 VX MT 8 STR'
#  'VDi Plus' '1.4 Sportz' 'S7 120' 'Delta BSIV' 'AT W6 1.99 mHawk' 'CRDe'
#  'Sportz 1.1L' 'EX i-Vtech' 'Green VXI' '1.4 Sigma' 'xDrive 20d xLine'
#  '350d 4MATIC' 'Exclusive E 200' '1.8 G CVT' '35 TDI Quattro Premium Plus'
#  'i-DTEC V MT' '1.2 CRDi Magna' 'Turbo Sportz' 'T6' 'Sharp CVT'
#  '1.6 VTVT E' '1.2 S i VTEC' '2.4 VX MT 8S BSIV' '3.0L Portfolio LWB'
#  '110PS RxZ 8 Seater' '1.4' '1.2 Kappa SX Option' '1.5 TDI Comfortline'
#  'J CVT' 'Platinum AT' 'i VTEC VX Option' 'i-VTEC V CVT' '1.2 S AT i VTEC'
#  '1.2 Kappa Sportz Option AT' '1.2 Revotron XZA' '1.6 CRDi SX Plus'
#  '1.6 CRDi AT SX Plus' 'T8' 'i VTEC SV' '1.6 TDI Elegance' 'XV D BSIV'
#  '110PS Diesel RxZ AMT' 'BSIV ZXI' '2.0 SX Option AT' 'VXI AT Optional'
#  'VXI AMT' 'SV MT' '1.2 Revotron XM Option' 'SX' 'LXI Minor Duo LPG'
#  'Asta Option' 'ZXI Optional MT BSIV' '5 Seater AC BSIV' 'EX MT'
#  '1.0 T Option' 'Magna 1.2' '1.2 MPI Comfortline' 'LT' 'HTK Plus G'
#  'SX Opt Diesel' 'W8 2WD' 'SX Diesel' '1.6 MPI Ambition Plus'
#  'SHVS ZDI Plus' 'VL AT' 'RXZ EASY-R AMT Dual Tone' '4x4 Opt'
#  'Exclusive E 220d' '520d Luxury Line' '300d' '2.0L 2WD AT' 'G CVT BSIV'
#  'Delta DDiS 200 SH' 'XV S' 'RS ZXi Plus' '1.8 GL' '1.6 E Plus' '1.4 Zeta'
#  'VXi' 'W11 AT BSIV' 'G SP' 'GT TSI' '2.4 VX MT BSIV'
#  'mFALCON D75 K8 5str' 'G' '1.6 VTVT AT S Option' 'VXi AT' 'Era' 'ZDi AMT'
#  '1.5 TDI Active' 'Elegance 1.8 TSI AT' 'ZDi Plus SHVS' 'LXI CNG'
#  'Elegance 2.0 TDI CR AT' '3.0 TDI' 'RxZ' '2.0 TDI' 'CNG VXI BSIV'
#  'CNG LXI BSIV' '200 CDI' '1.8 G' 'XZ Plus S' 'CRDi 1.6 AT SX Plus'
#  'AMG S63 Coupe' 'Extended Wheelbase BSIV' 'Sharp AT BSIV'
#  'Diesel Asta Option' 'ZX' 'G BSIV' 'Asta Opt Diesel'
#  'LX 4-Str Convert Top Diesel AT' '1.2 Revotron XZ Plus'
#  '85PS Diesel RxL Plus' '1.2 CVT Delta' 'RXT Turbo DT'
#  '1.6 SX Option Diesel' 'XV' '1.3 Turbo XV Pre Option' '1.4 S'
#  'LX 4-Str Hard Top' 'ZDI' 'Climber 1.0 AMT' '1.5 TDI Highline Plus'
#  'CRDi 1.6 SX' '1.6 VTVT SX' 'LXI Green (CNG)' 'Climber 1.0 MT'
#  'SX Petrol' 'VXI Optional MT BSIV' 'AMT ZXI BS IV' 'AT Asta'
#  '1.2 Kappa Sportz Option' '2.0 Limited Option' '1.5 TDI Style BSIV'
#  'i DTEC VX' '1.2 CRDi E Plus' '2.0 Longitude Option BSIV'
#  'Petrol Comfortline' 'i VTEC VX' 'i-VTEC SV' 'DDiS 320 Delta'
#  '1.2 Kappa S' 'DDiS 200 Zeta' 'AMT VXI Option' '1.5 S i DTEC'
#  '1.1 CRDi Base' 'TSI' '1.5 TDI AT Style Plus' 'RxE' '1.5 VDI'
#  'Climber 1.0 MT Opt' 'i VTEC S' '1.4 SX Dual Tone' '200' 'DI 4X4'
#  'XV D Premium Leather' 'i DTec VX Option' '1.6 SX CRDI (O) AT' '1.5 GX'
#  'GL' '1.2 S' '2.0 SX' 'XL CVT' '3.0L 4X4 AT' 'AT ZXi' 'Luxury Line'
#  '1.0 LS' 'Petrol RxE' '1.2 Magna' 'V' 'Asta Opt' '220 CDI AT'
#  '2.8 ZX AT BSIV' 'JS MT' '85PS RxE' '5 Seater AC' 'RXZ EASY-R AMT'
#  'XZ Plus 6 Str' 'M2 8Str BSIV' '1.6 SX Automatic Diesel' 'W10 1.99 mHawk'
#  'W6 BSIV' 'ZLX' 'Petrol Trendline 1.2L' 'VXI BSIII' '1.6 Gamma SX Plus'
#  'ZX MT' 'S2 9 Seater' 'VX Varicor 400' '2.4 ZX MT BSIV'
#  '1.2 Revotron XZ Option' 'GXi' 'Pleasure 4x4' 'i DTEC SV'
#  '1.5 Petrol Trend BSIV' '1.2 Lxi BSIV' '1.0 RXT' 'VX 8 Str'
#  'i-DTEC VX MT' 'Petrol Asta' 'B4' 'LX BSIII' '7 Seater Standard BSIV'
#  'Diesel Titanium' 'S7 140 BSIV' '1.0 S' 'VLX 2WD AIRBAG BSIV' 'VXI Minor'
#  '2.5 G (Diesel) 7 Seater BS IV' 'SLX 2WD BSIII'
#  '1.5 Revotorq XZ Plus Dual Tone' '1.4 CRDi' '1.4 Duratorq CLXI' 'EX'
#  'S3 Plus 9 Seater' 'SLE' 'Diesel ZXI' '1.5 TDCi Titanium'
#  '85PS Diesel RxE' 'VLS AT 2.2 mHAWK' 'Titanium Diesel BSIV'
#  'CNG 5 Seater AC BSIV' 'DICOR 2.2 EX 4x2' 'CNG VXI' '1.2 VTVT SX'
#  'Asta AMT' 'S Turbo BSIV' 'XZ Diesel' '1.4 CRDi S' 'Rubicon'
#  '4MATIC Coupe' 'xDrive 40i' 'GTX Plus Turbo iMT' 'XM S'
#  'CRDi 1.6 AT SX Option' '1.5 Revotorq XZ Plus'
#  'XZA Plus DT Roof AMT Diesel' 'XZA Plus AT' '1.2 VX MT'
#  'XZ Dark Edition BSIV' 'Neotech' 'S BSIV' '1.4 CRDi S Plus' 'V i-VTEC'
#  'G CVT' '85PS Diesel RxL Optional' '1.5 VX i DTEC' 'Zeta DDiS 200 SH'
#  '1.6 EX VTVT' 'Fashion Edition XL CVT' 'XZA Plus Dark Edition AT'
#  '1.2 VTVT E Plus' 'Hybrid Sharp MT BSIV' 'LDi' 'Sportz CRDi' 'XL Petrol'
#  '1.4 Sport Plus' '1.6 MPI Style BSIV' 'XZ Plus (O)' 'RXT Optional']
# ______________________________
#
# fuel :
#
# ['Petrol' 'Diesel' 'CNG' 'LPG' 'Electric']
# ______________________________
#
# Trans :
#
# ['Automatic' 'Manual']
# ______________________________
#
# Brand :
#
# ['Honda' 'Mahindra' 'Hyundai' 'Jeep' 'Toyota' 'Porsche' 'Rolls-Royce'
#  'BMW' 'Datsun' 'Maruti' 'Renault' 'Kia' 'Volkswagen' 'Tata' 'Nissan'
#  'Chevrolet' 'MG' 'Skoda' 'Ford' 'Land' 'Mercedes-Benz' 'Audi' 'Jaguar']
# ______________________________
#
# model :
#
# ['Jazz' 'Marazzo' 'Grand i10' 'Compass' 'Verna' 'XUV500' 'Camry' 'Brio'
#  'Creta' 'Boxster' 'Ghost' '7 Series' '3 Series' 'Land Cruiser' 'City'
#  'RediGO' 'Ciaz' 'Amaze' 'Ignis' 'Duster' 'i20' 'Alto K10' 'Seltos'
#  'Vento' 'Tucson' 'Alto 800' 'Wagon R' 'Swift Dzire' 'Tiago' 'Baleno'
#  'XUV300' 'KWID' 'Swift' 'SX4 S' 'Celerio' 'KUV 100' 'i10' 'Magnite' 'GO'
#  'EON' 'Ritz' 'Alto' 'Innova' 'Lodgy' 'X1' 'Cruze' 'CR-V' 'Beat' 'Thar'
#  'Hector' 'Octavia' 'Santro' 'Nexon' 'Yaris' 'Kushaq' 'Rapid' 'Ecosport'
#  'Rover Range' 'Wrangler' 'Figo' 'Venue' 'Hector Plus' 'Ameo' 'Kicks'
#  'Altroz' 'Aura' 'WR-V' 'S-Presso' 'Triber' 'Scorpio' 'Harrier' 'Micra'
#  'CLA' 'Q7' 'Cayenne' 'Kodiaq' 'GLA Class' 'Corolla Altis' 'Polo'
#  'New Laura' 'XL6' 'i20 Active' 'Vitara Brezza' 'Xcent' 'S-Class'
#  'A-Class Limousine' 'X7' 'F-Pace' 'Hexa' 'Ertiga' 'A6' 'TUV 300'
#  'Etios Liva' 'Fortuner' 'SX4' 'New Safari' 'Sunny' 'Captur' '5 Series'
#  'Endeavour' 'Innova Crysta' 'GLS' 'E-Class' 'Q3' 'BR-V' 'GO Plus' 'XJ'
#  'Ciaz S' 'Alcazar' 'Elantra' 'Eeco' 'Compass Trailhawk' 'GLE'
#  'Micra Active' 'Superb' 'Q5' 'Pulse' 'Kiger' 'Zen Estilo' 'Tigor' 'Scala'
#  'Nexon EV' 'Glanza' 'GLC' 'Platinum Etios' 'Santro Xing' 'Spark' 'Etios'
#  'C-Class' 'Bolero Power' 'Safari Storme' 'Aria' 'Supro' 'Bolero'
#  'Classic' 'Sumo' 'Fiesta' 'Freestyle' 'AMG C' 'Sonet' 'Mobilio']
# ______________________________

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in cat:
    df[i]=le.fit_transform(df[i])

# %%
for i in cat:
    print(i,":\n")
    print(df[i].unique())
    print('______________________________\n')
# Out:
# city :
#
# [ 1  2 10  7  5  4  3 11  6  8  0  9]
# ______________________________
#
# variant :
#
# [425 326 402  84  59 141 474 173 146 366 482 122 185 409 207 196 443  82
#  557 411 519 371  12 339 413 358 238 451 341 477  31 440 446 297  57 526
#  148 226  28 536 469 295  14 316 455 457 509  24 475  79  58 486 545 317
#  347 404 348 156 263 528 262   4 452 327 422 412 333 282  56 332  55 330
#  321  69  53 432 312 501 479 459 175 214 568 310 311 172 308 363 229  68
#  399  85 153 483 240  15 465  48 424  74 566   8 108 107 186 193 353 268
#  387 119 450 393  27 236 400 349 245   5 209 426  60  37 118 431 232 396
#  439  32 542 512  43 212 390 382 410 414 442 453 354  64 394 484 533 546
#   44 429 462  65 447 562 183 438  13 142 233 215 302 549 553 537 144  40
#   99 373 556 508 337 218 237 496 234 181 189 365 166 182 569 145 491 249
#  441  41  75 558 294 388 129 272 128  73 529 325 104 235 100 480 231 220
#   52 521 530 370  67 427 372  21 345 112  16 137  92 149 244  11 331 499
#  391   9 376 334 216 572 161   1 494 407 257 123 362  70 367 164 154  95
#   17 352 406  89  83 219 357 195 535 460 230 197  20 369 405 567 466 445
#  329 540 555 292 560 395 522  81 222  54 261  94 187 138 470 433 510 274
#  115 472 223 505 401 532  23 430  26 493  97 205 192 176 420 417 531 103
#  155  25 564 121 513   3 135 502  38 448 490 476 514 177 487 392 463 132
#  563  66 306 322 538 485 168 434  91 377 269 227 253 403 278 300  88 570
#  199 283 151 198 552  19 421 415 398 143  51 169 191 158  72  30 111 304
#  343 551 561  50  34  47 124 120 416 548 139 497 157 247 163 456 454 383
#   42 384 320 243 534 203 277   7 328  36 309 301 386 481 385 130 379 435
#  356 201 284 204 194 167 290 270 500 346 152 125  93 467 473 291 296 170
#  565 287 140 468 281 520 110 279 523 318 280 188 361 165 252 250 180 150
#  511 255 217 285 397 271 525 288 242 313  46 211  22 351 136 495  71  86
#  314 518 258 113 256 147 319 259 389 464 224 225  33 159 114 543  18 160
#  338 550 559 265  29 264 221 105  10 418 109 360 116 260 547  87 179 266
#  498 544 134  96 293  49 162 488 190 228 323   0 340  39 423 241 184 178
#  305 213 202 355 507 324 133 471 478 524 342 458 127 527 374 449 171  45
#  299 344 541  98  35   2 444 554 336 246 315 206 273 378   6 437 461 174
#  381 102  76  80 276 375 380 275 106 208 436 419 248 267 251  62 239 368
#  504  77 359 200 571 298 492 254 101 516 515  63 503 335 364  78 428 289
#  210 117 539 126 286 517  61 303 307 408 489  90 131 506 350]
# ______________________________
#
# fuel :
#
# [4 1 0 3 2]
# ______________________________
#
# Trans :
#
# [0 1]
# ______________________________
#
# Brand :
#
# [ 5 12  6  8 21 16 18  1  3 13 17  9 22 20 15  2 11 19  4 10 14  0  7]
# ______________________________
#
# model :
#
# [ 69  79  61  33 124 134  25  21  36  20  59   2   0  76  31  95  29  11
#   66  38 139   9 107 122 121   8 127 115 118  16 133  71 114 101  28  70
#  138  78  57  40  96   7  67  77 129  37  24  17 117  63  87 103  85 136
#   75  94  41  97 128  50 123  64  12  72  10  14 126  99 120 106  62  80
#   23  93  27  74  53  35  89  83 132 140 125 135  98   3 130  48  65  45
#    4 116  47  51 100  84 111  26   1  44  68  56  39  91  15  58 131  30
#    6  43  42  34  55  81 112  92  90  73 137 119 105  86  60  54  88 104
#  109  46  22  19 102  13 113  18  32 110  49  52   5 108  82]
# ______________________________

# %%
df.head()
# Out:
#    city  variant  fuel  Trans  reg_year  Brand  model  price(Lakh)  run(kms)
# 0     1      425     4      0      2016      5     69         6.28   39821.0
# 1     1      326     1      1      2018     12     79        10.15   41071.0
# 2     1      402     4      1      2015      6     61         4.51   67525.0
# 3     1       84     4      0      2019      8     33        16.78   32294.0
# 4     1       59     4      0      2016      5     69         6.29   15385.0

# %% [markdown]
# #### correlation matrix

# %%
cor=df.corr().abs()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(cor,annot=True,cmap='Blues')
plt.title("Correlation Matrix ")
plt.show()

# %% [markdown]
# * Correlation with Target Feature

# %%
cor_label=(df.drop('price(Lakh)',axis=1)).corrwith(df['price(Lakh)']).abs()
cor_label
# Out:
# city        0.002313
# variant     0.007437
# fuel        0.082614
# Trans       0.401959
# reg_year    0.109886
# Brand       0.005531
# model       0.010894
# run(kms)    0.080443
# dtype: float64

# %%
plt.figure(figsize=(5,3))
cor_label.plot(kind="bar",color=sns.color_palette('Accent_r'))
plt.title("Correlation with SalePrice Target",fontsize=8)
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.set_palette('Set1')
plt.style.use('default')
sns.scatterplot(x=df['reg_year'],y=df['run(kms)'])
plt.xlabel('reg_year',fontsize=10) 
plt.show()

# %% [markdown]
# * Multicollinearity with VIF

# %%
from statsmodels.stats.outliers_influence  import variance_inflation_factor

Predictors1=df.drop(columns=['price(Lakh)'],axis=1)
predictor1=Predictors1.to_numpy()

VIF1=pd.DataFrame()
VIF1["Features"]=Predictors1.columns
VIF1["vif_scores"]=[variance_inflation_factor(predictor1,i) for i in range(Predictors1.shape[1])]
VIF1.sort_values(by='vif_scores',ascending=False)
# Out:
#    Features  vif_scores
# 4  reg_year   27.214314
# 2      fuel    7.797965
# 5     Brand    5.109763
# 3     Trans    4.672998
# 1   variant    3.876287
# 6     model    3.641569
# 0      city    3.583648
# 7  run(kms)    2.524742

# %%
Predictors2=df.drop(columns=['price(Lakh)','reg_year'],axis=1)
predictor2=Predictors2.to_numpy()
VIF2=pd.DataFrame()
VIF2["Features"]=Predictors2.columns
VIF2["vif_scores"]=[variance_inflation_factor(predictor2,i) for i in range(Predictors2.shape[1])]
VIF2.sort_values(by='vif_scores',ascending=False)
# Out:
#    Features  vif_scores
# 2      fuel    4.940996
# 3     Trans    4.227073
# 4     Brand    4.173260
# 1   variant    3.513377
# 0      city    3.277254
# 5     model    3.239323
# 6  run(kms)    2.118377

# %% [markdown]
# * Skewnes analysis

# %%
df[inf].skew()
# Out:
# reg_year    -0.495958
# run(kms)    11.869860
# dtype: float64

# %%
plt.figure(figsize=(5,3))
df[inf].skew().plot.bar(color=sns.color_palette('Set1'))
plt.title('Skewness of continuous feature')
plt.xticks(fontsize=8)

plt.show()

# %%
plt.figure(figsize=(5,3))
df[inf].skew().plot.bar(color=sns.color_palette('Set1'))
plt.title('Skewness of continuous feature')
plt.xticks(fontsize=5)
plt.show()

# %%
data=df.copy()
data.shape
# Out:
# (7939, 9)

# %%
data[inf].skew()
# Out:
# reg_year    -0.495958
# run(kms)    11.869860
# dtype: float64

# %% [markdown]
# * Transformation analysis

# %%
from sklearn.preprocessing import PowerTransformer

transform1=pd.DataFrame()
pwr1=PowerTransformer(method='yeo-johnson')
transform1[inf]=pwr1.fit_transform(data[inf])
transform1[inf].skew()
# Out:
# reg_year   -0.330645
# run(kms)    0.131317
# dtype: float64

# %%
transform1[inf].skew().plot.bar(color='lightgreen',title='Power Transformation',figsize=(5,3))
# Out:
# <AxesSubplot:title={'center':'Power Transformation'}>

# %% [markdown]
# * Sqaure root transformation

# %%
transform2=pd.DataFrame()
transform2=np.sqrt(data[inf])
transform2.skew()
# Out:
# reg_year   -0.497826
# run(kms)    1.361335
# dtype: float64

# %%
transform2.skew().plot.bar(color='lightgreen',title='Sqaureroot Transformation',figsize=(5,3))
# Out:
# <AxesSubplot:title={'center':'Sqaureroot Transformation'}>

# %% [markdown]
# * Cuberoot transformation

# %%
transform3=pd.DataFrame()
transform3=np.cbrt(data[inf])
transform3.skew()
# Out:
# reg_year   -0.498449
# run(kms)    0.249648
# dtype: float64

# %%
transform3.skew().plot.bar(color='violet',title='Cuberoot Transformation',figsize=(5,3))
# Out:
# <AxesSubplot:title={'center':'Cuberoot Transformation'}>

# %% [markdown]
# * log transformation

# %%
transform4=pd.DataFrame()
transform4=np.log(data[inf])
transform4.skew()
# Out:
# reg_year   -0.499695
# run(kms)   -0.985274
# dtype: float64

# %%
transform4.skew().plot.bar(color='violet',title='log Transformation',figsize=(3,1))
# Out:
# <AxesSubplot:title={'center':'log Transformation'}>

# %% [markdown]
# *  Transformation with Power Transformer yeo johnsosn method

# %%
power=PowerTransformer(method='yeo-johnson')
df[inf]=power.fit_transform(df[inf])

# %%
df[inf].skew()
# Out:
# reg_year   -0.330645
# run(kms)    0.131317
# dtype: float64

# %%
fig,axs=plt.subplots(1,2)
data[inf].skew().plot.bar(ax=axs[0],color='red',title='Before',figsize=(5,3))
df[inf].skew().plot.bar(ax=axs[1],color='lightgreen',title='After')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.set_palette('bright')
graph=1

for column in inf:
    if graph<=len(inf):
        ax=plt.subplot(1,2,graph)
        sns.distplot(data[column],color='blue')
        sns.distplot(df[column],color='red')
        plt.xlabel(column,fontsize=5)
        plt.legend(['Before Transformation','After Transformation'])
        
    graph+=1
plt.show()
plt.tight_layout()

# %% [markdown]
# * Splitting data into features and response
#
# Eleminating reg_year from dataset to remove high multicollinearity.

# %%
x1=df.drop(['price(Lakh)'],axis=1)
y1=df['price(Lakh)']

# %%
print('x1 shape is ',x1.shape)
print('y1 shape is ',y1.shape)
# Out:
# x1 shape is  (7939, 8)
# y1 shape is  (7939,)

# %% [markdown]
# ### standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x1)

# %%
x_scaled.shape
# Out:
# (7939, 8)

# %% [markdown]
# ## PCA
# Dimesionlaity reduction is applied due to :
#
#  1] The correlation of features with target variable is very low order of less than 0.1
#
#  2] The vif score obtained for reg_year due to multicollinearity exists between reg_year variable and other varibale
#
#  3] The reg_year is one of correlated variable with target among all variable with 0.109
#
#  4] The reg_year and run variable has moderate correlation amog them 0.35

# %%
from sklearn.decomposition import PCA

pca=PCA()
pca.fit_transform(x_scaled)
# Out:
# array([[-0.19027151,  0.12113225, -0.68281257, ..., -0.53888384,
#          1.26766749, -0.0376219 ],
#        [ 0.62148961,  0.92669372,  0.09609115, ...,  0.0800719 ,
#         -0.99055218, -0.30837538],
#        [ 1.00519328, -0.05412852, -1.82785887, ..., -0.23746803,
#          0.40606204,  0.17987144],
#        ...,
#        [-0.97321448, -0.10175526,  1.27193301, ...,  1.54995028,
#          0.39896257,  0.22595373],
#        [ 1.29908489, -0.55914175,  0.01482914, ..., -1.43685816,
#          1.68981358, -0.97678755],
#        [ 0.2068068 , -0.06831936,  0.21902214, ..., -0.45046333,
#          0.64126668,  0.04937854]])

# %%
plt.figure(figsize=(20,10))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Components',fontsize=20)
plt.ylabel('Variance Explained',fontsize=20)
plt.title('PCA analysis- explained_variance',fontsize=20)
plt.yticks(np.arange(0,1.05,0.05),fontsize=20)
plt.xticks(range(0,8),fontsize=10)
plt.show()

# %%
pd.DataFrame(data=np.cumsum(pca.explained_variance_ratio_))
# Out:
#           0
# 0  0.222592
# 1  0.366014
# 2  0.497916
# 3  0.626517
# 4  0.750753
# 5  0.856398
# 6  0.949920
# 7  1.000000

# %%
pca1=PCA(n_components=8) 
dim1=pca1.fit_transform(x_scaled)
x_dim1=pd.DataFrame(dim1,columns=[('PC{}').format(i) for i in range(1,9)])
x_dim1
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0    -0.190272  0.121132 -0.682813  2.122604  0.898442 -0.538884  1.267667
# 1     0.621490  0.926694  0.096091 -0.292900  1.624873  0.080072 -0.990552
# 2     1.005193 -0.054129 -1.827859  0.399589  0.477121 -0.237468  0.406062
# 3    -1.329681 -1.322901  0.144215  1.513628  1.578918  0.288602  0.472350
# 4    -0.900522 -1.092519 -0.169728  1.991912  1.212078  1.044631  1.036123
# ...        ...       ...       ...       ...       ...       ...       ...
# 7934  1.577175  1.551561  1.304155 -0.446221 -0.580560 -0.192869 -0.826129
# 7935 -1.085890  0.144365  1.671853  0.884506 -0.621471  0.468417  1.092507
# 7936 -0.973214 -0.101755  1.271933 -1.702867 -0.677001  1.549950  0.398963
# 7937  1.299085 -0.559142  0.014829 -1.793330 -1.126956 -1.436858  1.689814
# 7938  0.206807 -0.068319  0.219022 -1.234723 -1.060491 -0.450463  0.641267
#
#            PC8
# 0    -0.037622
# 1    -0.308375
# 2     0.179871
# 3     0.452684
# 4    -0.887475
# ...        ...
# 7934  0.655379
# 7935  0.609569
# 7936  0.225954
# 7937 -0.976788
# 7938  0.049379
#
# [7939 rows x 8 columns]

# %%
x_dim1.shape
# Out:
# (7939, 8)

# %%
y1.shape
# Out:
# (7939,)

# %%
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso,Ridge

from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.ensemble import AdaBoostRegressor

from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error ,mean_absolute_error,r2_score 
from sklearn.model_selection import cross_val_score

# %%
maxR2=0
maxRn=0
for i  in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x_dim1,y1,test_size=0.5,random_state=i)
    regr=DecisionTreeRegressor(random_state=10)
    regr.fit(x_train,y_train)
    r2=regr.score(x_test,y_test)
    print("R squared ",r2,'Random sate ',i)
    
    if r2>maxR2:
        maxR2=r2
        maxRn=i
        print("R-squared",maxR2,"random_state",i)
# Out:
# R squared  0.9546275247478017 Random sate  1
# R-squared 0.9546275247478017 random_state 1
# R squared  0.9710759913555702 Random sate  2
# R-squared 0.9710759913555702 random_state 2
# R squared  0.9766961575377525 Random sate  3
# R-squared 0.9766961575377525 random_state 3
# R squared  0.9581928149874078 Random sate  4
# R squared  0.9563140633001774 Random sate  5
# R squared  0.914199784566073 Random sate  6
# R squared  0.9636199690176062 Random sate  7
# R squared  0.9492587843423441 Random sate  8
# R squared  0.9739337022451766 Random sate  9
# R squared  0.9697218903158387 Random sate  10
# R squared  0.9702439707181427 Random sate  11
# R squared  0.9667509139594264 Random sate  12
# R squared  0.9705478850648861 Random sate  13
# R squared  0.9787528380082158 Random sate  14
# R-squared 0.9787528380082158 random_state 14
# R squared  0.9343431512542318 Random sate  15
# R squared  0.9695201495884556 Random sate  16
# R squared  0.9886432881218524 Random sate  17
# R-squared 0.9886432881218524 random_state 17
# R squared  0.9810461494498935 Random sate  18
# R squared  0.9803591293612142 Random sate  19
# R squared  0.9219188394931254 Random sate  20
# R squared  0.9828357717837264 Random sate  21
# R squared  0.9762724996197538 Random sate  22
# R squared  0.9779593343147706 Random sate  23
# R squared  0.9760632974478626 Random sate  24
# R squared  0.9899372491576998 Random sate  25
# R-squared 0.9899372491576998 random_state 25
# R squared  0.9638461878158029 Random sate  26
# R squared  0.9662388598710029 Random sate  27
# R squared  0.9738897548811717 Random sate  28
# R squared  0.9797542465540136 Random sate  29
# R squared  0.9908944060336045 Random sate  30
# R-squared 0.9908944060336045 random_state 30
# R squared  0.986750511115106 Random sate  31
# R squared  0.9827262854280707 Random sate  32
# R squared  0.9504437052122731 Random sate  33
# R squared  0.9720710189847207 Random sate  34
# R squared  0.94957232212916 Random sate  35
# R squared  0.9933112938277917 Random sate  36
# R-squared 0.9933112938277917 random_state 36
# R squared  0.9901526032740562 Random sate  37
# R squared  0.9937745650248873 Random sate  38
# R-squared 0.9937745650248873 random_state 38
# R squared  0.9739351012590114 Random sate  39
# R squared  0.9983507247301104 Random sate  40
# R-squared 0.9983507247301104 random_state 40
# R squared  0.9426889930666642 Random sate  41
# R squared  0.9578310837920736 Random sate  42
# R squared  0.9685106040236547 Random sate  43
# R squared  0.9778617905225626 Random sate  44
# R squared  0.9612994740791483 Random sate  45
# R squared  0.9644590123616635 Random sate  46
# R squared  0.9828764891899536 Random sate  47
# R squared  0.9953563563136765 Random sate  48
# R squared  0.9827805842124536 Random sate  49
# R squared  0.7730955947784405 Random sate  50
# R squared  0.8118381708260727 Random sate  51
# R squared  0.9765395276136657 Random sate  52
# R squared  0.9726628664970536 Random sate  53
# R squared  0.9485969505973293 Random sate  54
# R squared  0.9856078717013415 Random sate  55
# R squared  0.9969456929937223 Random sate  56
# R squared  0.9946974841527371 Random sate  57
# R squared  0.9770486609530866 Random sate  58
# R squared  0.982552469767736 Random sate  59
# R squared  0.9724245319153934 Random sate  60
# R squared  0.9602336708768144 Random sate  61
# R squared  0.9927013508415953 Random sate  62
# R squared  0.9505744991491252 Random sate  63
# R squared  0.9727911548792579 Random sate  64
# R squared  0.9819749645464165 Random sate  65
# R squared  0.9953649494874941 Random sate  66
# R squared  0.9965569268419919 Random sate  67
# R squared  0.9963097540085935 Random sate  68
# R squared  0.9791818263907457 Random sate  69
# R squared  0.9908580939155064 Random sate  70
# R squared  0.9897232878177441 Random sate  71
# R squared  0.9723285737945568 Random sate  72
# R squared  0.9755379119323805 Random sate  73
# R squared  0.9737721644172992 Random sate  74
# R squared  0.9858345536941299 Random sate  75
# R squared  0.9805988608220426 Random sate  76
# R squared  0.9847117240242582 Random sate  77
# R squared  0.9531505242645677 Random sate  78
# R squared  0.9700804410054757 Random sate  79
# R squared  0.9863095606506825 Random sate  80
# R squared  0.9581619773869622 Random sate  81
# R squared  0.9870037290668563 Random sate  82
# R squared  0.9592219188072569 Random sate  83
# R squared  0.9647802898081552 Random sate  84
# R squared  0.9902999806583475 Random sate  85
# R squared  0.9749059396815668 Random sate  86
# R squared  0.9670211069808123 Random sate  87
# R squared  0.9836583665391821 Random sate  88
# R squared  0.982501175135354 Random sate  89
# R squared  0.9854987161163056 Random sate  90
# R squared  0.9861372089260722 Random sate  91
# R squared  0.9968546466740835 Random sate  92
# R squared  0.9697976925655291 Random sate  93
# R squared  0.9928890139310577 Random sate  94
# R squared  0.9979787165489601 Random sate  95
# R squared  0.9815527576302794 Random sate  96
# R squared  0.9748710028623008 Random sate  97
# R squared  0.9866009759307345 Random sate  98
# R squared  0.9563725551665612 Random sate  99
# R squared  0.9883597351012626 Random sate  100
# R squared  0.9518198754497376 Random sate  101
# R squared  0.9964940912327372 Random sate  102
# R squared  0.968948024079377 Random sate  103
# R squared  0.9970492548446966 Random sate  104
# R squared  0.9683208796615668 Random sate  105
# R squared  0.9875437488639319 Random sate  106
# R squared  0.9929573443420417 Random sate  107
# R squared  0.9782102352522065 Random sate  108
# R squared  0.9921247063918587 Random sate  109
# R squared  0.9724185371298381 Random sate  110
# R squared  0.8856518591242537 Random sate  111
# R squared  0.9760867492134555 Random sate  112
# R squared  0.9619494306266347 Random sate  113
# R squared  0.9906185179205651 Random sate  114
# R squared  0.9587046014862538 Random sate  115
# R squared  0.9958497292465454 Random sate  116
# R squared  0.9870422209601771 Random sate  117
# R squared  0.9818409912077396 Random sate  118
# R squared  0.9914888742229262 Random sate  119
# R squared  0.9854279218856259 Random sate  120
# R squared  0.9453258256628521 Random sate  121
# R squared  0.9850121423133127 Random sate  122
# R squared  0.9370135322489074 Random sate  123
# R squared  0.9898722213415715 Random sate  124
# R squared  0.9840729509673026 Random sate  125
# R squared  0.9941862906884484 Random sate  126
# R squared  0.9695059057430302 Random sate  127
# R squared  0.9659196861709491 Random sate  128
# R squared  0.9944683285875552 Random sate  129
# R squared  0.9446871066789009 Random sate  130
# R squared  0.9651181644464113 Random sate  131
# R squared  0.9879975300223689 Random sate  132
# R squared  0.969697213421501 Random sate  133
# R squared  0.9531174282931387 Random sate  134
# R squared  0.996988369742035 Random sate  135
# R squared  0.9932428809443087 Random sate  136
# R squared  0.9748444088691568 Random sate  137
# R squared  0.9958175249485355 Random sate  138
# R squared  0.968143348772623 Random sate  139
# R squared  0.9615260376529992 Random sate  140
# R squared  0.9798716563972972 Random sate  141
# R squared  0.9954941194610174 Random sate  142
# R squared  0.9854555864619614 Random sate  143
# R squared  0.9796578498249641 Random sate  144
# R squared  0.9804440765071337 Random sate  145
# R squared  0.997854863962119 Random sate  146
# R squared  0.9937820139756152 Random sate  147
# R squared  0.9751690099405308 Random sate  148
# R squared  0.9733252047543745 Random sate  149
# R squared  0.966188410670632 Random sate  150
# R squared  0.9482445932804485 Random sate  151
# R squared  0.9890935252345819 Random sate  152
# R squared  0.8575473158588576 Random sate  153
# R squared  0.9576706394958322 Random sate  154
# R squared  0.9756193828086487 Random sate  155
# R squared  0.979378842439291 Random sate  156
# R squared  0.9099549074281889 Random sate  157
# R squared  0.9728235323287289 Random sate  158
# R squared  0.9891884121219147 Random sate  159
# R squared  0.997211018256488 Random sate  160
# R squared  0.9601344252871766 Random sate  161
# R squared  0.9587940949196808 Random sate  162
# R squared  0.9867221122812074 Random sate  163
# R squared  0.9662649194118653 Random sate  164
# R squared  0.9787463647833389 Random sate  165
# R squared  0.9542575129182909 Random sate  166
# R squared  0.8410393014110666 Random sate  167
# R squared  0.975933384834594 Random sate  168
# R squared  0.9572180690704833 Random sate  169
# R squared  0.9774238843733825 Random sate  170
# R squared  0.9438750839923684 Random sate  171
# R squared  0.9799246437637346 Random sate  172
# R squared  0.9793388879901489 Random sate  173
# R squared  0.971189096457669 Random sate  174
# R squared  0.9761373746748666 Random sate  175
# R squared  0.9965590253840227 Random sate  176
# R squared  0.9692648744043346 Random sate  177
# R squared  0.9346690955715176 Random sate  178
# R squared  0.9954220308027818 Random sate  179
# R squared  0.9893003300236894 Random sate  180
# R squared  0.9779687334962914 Random sate  181
# R squared  0.980888848925356 Random sate  182
# R squared  0.9871217771371668 Random sate  183
# R squared  0.9391211760810465 Random sate  184
# R squared  0.9695551033303523 Random sate  185
# R squared  0.9873497166557099 Random sate  186
# R squared  0.9369082444629586 Random sate  187
# R squared  0.9911872400397961 Random sate  188
# R squared  0.9656519323431596 Random sate  189
# R squared  0.9601695625233417 Random sate  190
# R squared  0.964033839475215 Random sate  191
# R squared  0.994974195974764 Random sate  192
# R squared  0.9564718989778825 Random sate  193
# R squared  0.9826999627497037 Random sate  194
# R squared  0.9566687413352593 Random sate  195
# R squared  0.9887674133220917 Random sate  196
# R squared  0.8726482104996545 Random sate  197
# R squared  0.9786175156181897 Random sate  198
# R squared  0.9783398429494153 Random sate  199

# %%
print("Maximum R squared obtained  is ",maxR2,'at random state',maxRn)
# Out:
# Maximum R squared obtained  is  0.9983507247301104 at random state 40

# %%
x_train,x_test,y_train,y_test=train_test_split(x_dim1,y1,test_size=0.5,random_state=40)

# %%
def Reg_eval(regr,x_train,y_train,x_test,y_test,train=True):
    if train==True:
        print('********** Training Evaluation *******************')
        ytrain_pred=regr.predict(x_train)
        
        R2_train=r2_score(y_train,ytrain_pred)
        RMSE_train=np.sqrt(mean_squared_error(y_train,ytrain_pred))
        print("\nThe R squared  for Train data  is {} ".format(R2_train))
        print("-"*60)
        print("\nThe RMSE for Train data is {} ".format(RMSE_train))
        
        
        
    elif train==False:
        print('\n********** Testing  Evaluation *******************')
        ytest_pred=regr.predict(x_test)
        R2_test=r2_score(y_test,ytest_pred)
        RMSE_test=np.sqrt(mean_squared_error(y_test,ytest_pred))
        MSE_test=mean_squared_error(y_test,ytest_pred)
        MAE_test=mean_absolute_error(y_test,ytest_pred)
        print(" \nThe R squared  for Test data is {} ".format(R2_test))
        print("-"*60)
        print("\nThe RMSE for  Test data  is {} ".format(RMSE_test))
        print("-"*60)
        print("\nThe  MSE for Test data  is {} ".format(MSE_test))
        print("-"*60)
        print("\nThe MAE for Test data  is {} ".format(MAE_test))
        print("-"*60)
        
def Reg_plot(regr,x_test,y_test):

    sns.set_palette(['red','lightgreen'])
    y_pred_test=regr.predict(x_test)
    fig=plt.figure(figsize=(15,10))
    fig.add_subplot(2,2,1)
    ax1=sns.scatterplot(x=y_test,y=y_test)
    sns.scatterplot(x=y_test,y=y_pred_test,ax=ax1)
    plt.xlabel("Actual Sales",fontsize=10)
    plt.xticks(fontsize=10)
    plt.ylabel("Predicted sales",fontsize=10)
    plt.yticks(fontsize=10)
    plt.legend(["Actual Price","Predicted Predicted"])
    plt.title("{} Prediction VS Actual data".format(type(regr)),fontsize=10)
   
    fig.add_subplot(2,2,2)
    sns.distplot(y_test-y_pred_test)
    plt.title("Distribution of Residuals in actual and Predicted values",fontsize=10)
    plt.xlabel('Errors',fontsize=10)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)
    
    fig.add_subplot(2,2,3)
 
    ax2=sns.kdeplot(y_test)
    sns.kdeplot(y_pred_test,ax=ax2)
    plt.title("Distribution of actual and Predicted values",fontsize=10) 
    plt.yticks(fontsize=10)
    plt.xticks(fontsize=10)
    plt.legend(["Actual Price","Predicted Predicted"])
    
    plt.show()

# %% [markdown]
# * Linear regression

# %%
Lr1=LinearRegression()
Lr1.fit(x_train,y_train)

Reg_eval(Lr1,x_train,y_train,x_test,y_test,train=True)
Reg_eval(Lr1,x_train,y_train,x_test,y_test,train=False)
# Out:
# ********** Training Evaluation *******************
#
# The R squared  for Train data  is 0.20886906717689924
# ------------------------------------------------------------
#
# The RMSE for Train data is 15.04228981479175
#
# ********** Testing  Evaluation *******************
#
# The R squared  for Test data is 0.1866330049685342
# ------------------------------------------------------------
#
# The RMSE for  Test data  is 18.605228083294815
# ------------------------------------------------------------
#
# The  MSE for Test data  is 346.1545120314221
# ------------------------------------------------------------
#
# The MAE for Test data  is 6.99873339361101
# ------------------------------------------------------------

# %%
Reg_plot(Lr1,x_test,y_test)

# %% [markdown]
# * Decision Tree regressor

# %%
dt1=DecisionTreeRegressor()
dt1.fit(x_train,y_train)

Reg_eval(dt1,x_train,y_train,x_test,y_test,train=True)
Reg_eval(dt1,x_train,y_train,x_test,y_test,train=False)
# Out:
# ********** Training Evaluation *******************
#
# The R squared  for Train data  is 1.0
# ------------------------------------------------------------
#
# The RMSE for Train data is 6.411328943056949e-16
#
# ********** Testing  Evaluation *******************
#
# The R squared  for Test data is 0.9968973556971381
# ------------------------------------------------------------
#
# The RMSE for  Test data  is 1.1490997242721879
# ------------------------------------------------------------
#
# The  MSE for Test data  is 1.320430176322418
# ------------------------------------------------------------
#
# The MAE for Test data  is 0.14260957178841324
# ------------------------------------------------------------

# %%
Reg_plot(dt1,x_test,y_test)

# %% [markdown]
# * GradientBoosting trgressor

# %%
gbdt1=GradientBoostingRegressor(learning_rate=0.1,min_samples_split=35,max_depth=5,min_samples_leaf=2,random_state=10)
gbdt1.fit(x_train,y_train)

Reg_eval(gbdt1,x_train,y_train,x_test,y_test,train=True)
Reg_eval(gbdt1,x_train,y_train,x_test,y_test,train=False)
# Out:
# ********** Training Evaluation *******************
#
# The R squared  for Train data  is 0.9787299898466568
# ------------------------------------------------------------
#
# The RMSE for Train data is 2.4664573933158307
#
# ********** Testing  Evaluation *******************
#
# The R squared  for Test data is 0.9701575552309196
# ------------------------------------------------------------
#
# The RMSE for  Test data  is 3.563763906837458
# ------------------------------------------------------------
#
# The  MSE for Test data  is 12.700413183677382
# ------------------------------------------------------------
#
# The MAE for Test data  is 1.820455652818321
# ------------------------------------------------------------

# %%
Reg_plot(gbdt1,x_test,y_test)

# %% [markdown]
# * RandomForestRegressor

# %%
rf1=RandomForestRegressor(max_depth=15,criterion='squared_error',min_samples_leaf=10,min_samples_split=15)
rf1.fit(x_train,y_train)

Reg_eval(rf1,x_train,y_train,x_test,y_test,train=True)
Reg_eval(rf1,x_train,y_train,x_test,y_test,train=False)
# Out:
# ********** Training Evaluation *******************
#
# The R squared  for Train data  is 0.7726867101485091
# ------------------------------------------------------------
#
# The RMSE for Train data is 8.063102539021052
#
# ********** Testing  Evaluation *******************
#
# The R squared  for Test data is 0.6877356568851682
# ------------------------------------------------------------
#
# The RMSE for  Test data  is 11.527972281628205
# ------------------------------------------------------------
#
# The  MSE for Test data  is 132.89414492598823
# ------------------------------------------------------------
#
# The MAE for Test data  is 3.08440158892867
# ------------------------------------------------------------

# %%
Reg_plot(rf1,x_test,y_test)

# %% [markdown]
# * XGBRegressor

# %%
xgr1=XGBRegressor(booster='gbtree',learning_rate=0.1,random_state=155,max_depth=6,gamma=0.1)

xgr1.fit(x_train,y_train)

Reg_eval(xgr1,x_train,y_train,x_test,y_test,train=True)
Reg_eval(xgr1,x_train,y_train,x_test,y_test,train=False)
# Out:
# ********** Training Evaluation *******************
#
# The R squared  for Train data  is 0.9938436233207173
# ------------------------------------------------------------
#
# The RMSE for Train data is 1.326943285626843
#
# ********** Testing  Evaluation *******************
#
# The R squared  for Test data is 0.9921046051424852
# ------------------------------------------------------------
#
# The RMSE for  Test data  is 1.8330683247030566
# ------------------------------------------------------------
#
# The  MSE for Test data  is 3.3601394830296702
# ------------------------------------------------------------
#
# The MAE for Test data  is 1.1153178555196719
# ------------------------------------------------------------

# %%
Reg_plot(xgr1,x_test,y_test)

# %% [markdown]
# * Model Evaluations

# %%
regressors=[dt1,gbdt1,xgr1,rf1]
Names=["DecisionTreeRegressor",'GBDTRegressor',
       'XGBRegressor',"RandomForestRegressor"]

# %%
scores_train= []
scores_test=[]
rmse_scores=[]
for reg in regressors:
    ypred_train=reg.predict(x_train)
    ypred_test=reg.predict(x_test)
    trainsc = r2_score(y_train,ypred_train)
    testsc=r2_score(y_test,ypred_test)
    rmse=np.sqrt(mean_squared_error(y_test,ypred_test))
    
    scores_train.append(trainsc)
    scores_test.append(testsc)
    rmse_scores.append(rmse)

# %%
for i in [5,10,15,20,25,30]:
    cvm=cross_val_score(DecisionTreeRegressor(random_state=30),x_dim1,y1,cv=i,scoring='r2')
    print("cross validation scores  : ",cvm)
    print("R2 square is {0} for cv={1}".format(cvm.mean(),i))
    print('-'*60)
# Out:
# cross validation scores  :  [ 0.01852273  0.07709178  0.51824675  0.26794256 -0.78561728]
# R2 square is 0.019237308645596207 for cv=5
# ------------------------------------------------------------
# cross validation scores  :  [0.34100996 0.79094443 0.97566971 0.99182109 0.66625606 0.1184685
#  0.65524779 0.9951933  0.4582287  0.17115406]
# R2 square is 0.6163993607913938 for cv=10
# ------------------------------------------------------------
# cross validation scores  :  [ 1.          0.89466709  0.60882921  0.98826741  0.99011705  0.99414046
#   0.99928753  0.98655619  0.24861753  0.94495683  1.          0.99724023
#  -1.67442093  0.54450848  0.97934317]
# R2 square is 0.7001406842283963 for cv=15
# ------------------------------------------------------------
# cross validation scores  :  [ 1.          0.89387172  1.          0.4097326   0.96816251  1.
#   0.98858592  1.          0.99827882  1.          0.99433003  0.19689669
#   1.          0.99559837  0.99717078  0.98391094 -2.1762991   1.
#   0.95401264  0.9730588 ]
# R2 square is 0.7588655363787408 for cv=20
# ------------------------------------------------------------
# cross validation scores  :  [ 1.          0.99945789  0.86121801  1.         -0.30369219  1.
#   1.          1.          0.99681848  1.          0.99816516  1.
#   0.98435193  1.          0.29326321  1.          0.99615439  1.
#   0.99498687  1.          0.04949446  1.          0.1157147   1.
#   0.97064886]
# R2 square is 0.8382632711263978 for cv=25
# ------------------------------------------------------------
# cross validation scores  :  [1.         1.         0.8900221  1.         0.46740009 1.
#  1.         1.         1.         0.99745218 0.99064707 1.
#  0.99637319 1.         1.         0.99350768 1.         0.45278315
#  1.         1.         1.         1.         0.99714064 1.
#  0.02565584 0.97792491 1.         0.70353029 1.         0.96126047]
# R2 square is 0.9151232536339136 for cv=30
# ------------------------------------------------------------

# %% [markdown]
# * The cv parameter affects generalized score hence cv=20 is optimum cv

# %%
from sklearn.model_selection import cross_val_score
cv_scores_mean=[]

for reg in regressors:
    scr=cross_val_score(reg,x_dim1,y1,cv=20,scoring="r2").mean()
   
    cv_scores_mean.append(scr)
cv_scores_mean
# Out:
# [0.898182656927833,
#  0.8603113708821475,
#  0.9162036836742635,
#  0.14701332086056618]

# %% [markdown]
# * Table for model evaluation

# %%
EvalDF=pd.DataFrame({'Regressor':Names,'Train R2 square':scores_train,'Test R2 square':scores_test,
                      'RMSE':rmse_scores,'Validation score':cv_scores_mean})

# %%
EvalDF["Analysing Overfitting model"]=EvalDF['Test R2 square']-EvalDF['Validation score']

# %%
EvalDF.sort_values(by="Analysing Overfitting model",ascending=True)
# Out:
#                Regressor  Train R2 square  Test R2 square       RMSE  \
# 2           XGBRegressor         0.993844        0.992105   1.833068
# 0  DecisionTreeRegressor         1.000000        0.996897   1.149100
# 1          GBDTRegressor         0.978730        0.970158   3.563764
# 3  RandomForestRegressor         0.772687        0.687736  11.527972
#
#    Validation score  Analysing Overfitting model
# 2          0.916204                     0.075901
# 0          0.898183                     0.098715
# 1          0.860311                     0.109846
# 3          0.147013                     0.540722

# %% [markdown]
# #### Hyperparameter tunning

# %%
from sklearn.model_selection  import GridSearchCV

param2={'gamma':[0.05,0.08,0.1,0.3,],
                 'learning_rate':[0.05,0.08,0.1,0.3],
                   'max_depth':[3,4,5,6,7,8],
         'min_child_weight':[0.8,0.9]}


grid2=GridSearchCV(XGBRegressor(),param_grid=param2,cv=20)
grid2.fit(x_train,y_train)  
print(grid2.best_params_)
# Out:
# {'gamma': 0.08, 'learning_rate': 0.3, 'max_depth': 5, 'min_child_weight': 0.8}

# %%
xgr2=grid2.best_estimator_
xgr2.fit(x_train,y_train)

Reg_eval(xgr2,x_train,y_train,x_test,y_test,train=True)
Reg_eval(xgr2,x_train,y_train,x_test,y_test,train=False)
# Out:
# ********** Training Evaluation *******************
#
# The R squared  for Train data  is 0.9989176378281661
# ------------------------------------------------------------
#
# The RMSE for Train data is 0.5563858439553148
#
# ********** Testing  Evaluation *******************
#
# The R squared  for Test data is 0.9963330073575759
# ------------------------------------------------------------
#
# The RMSE for  Test data  is 1.2492424832969116
# ------------------------------------------------------------
#
# The  MSE for Test data  is 1.5606067820738343
# ------------------------------------------------------------
#
# The MAE for Test data  is 0.5653717999176054
# ------------------------------------------------------------

# %%
Reg_plot(xgr2,x_test,y_test)

# %% [markdown]
# ##### The xgr1 is Extreme Gradient Boosting algorithm with gamma : 0.1, learning_rate : 0.3, max_depth: 5, min_child_weight : 0.8 is final model.
#
# 1] R2 score for train =0.0.9985
#
# 2] R2 score for test =0.9974
#
# 3] Root mean sqaure error for test = 0.9907
#
# 4] Mean sqaure error = 0.9816
#
# 5] Mean absolute error =0.6025

# %%
import joblib
joblib.dump(xgr2,"CarPrPred.pkl")
# Out:
# ['CarPrPred.pkl']
